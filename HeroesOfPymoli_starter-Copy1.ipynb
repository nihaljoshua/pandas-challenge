# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
file_to_load = ("Resources/purchase_data.csv")

# Read Purchasing File and store into Pandas data frame
purchase_data_df = pd.read_csv(file_to_load)

# %%
purchase_data_df.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %% [markdown]
# ## Player Count

# %% [markdown]
# * Display the total number of players

# %%
player_count = len(purchase_data_df["SN"])

# %%
print(player_count)
# Out:
# 780

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
unique_item_count = len(purchase_data_df["Item Name"].unique())

average_price = purchase_data_df["Price"].mean()

# %%
summary_df = pd.DataFrame({"Number of Unique Items": [unique_item_count],
                              "Average Price": average_price})
summary_df
# Out:
#    Number of Unique Items  Average Price
# 0                     179       3.050987

# %% [markdown]
# ## Gender Demographics

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
count_male_players = purchase_data_df.loc[purchase_data_df["Gender"] == "Male"]
count_male_players
male_count = len(count_male_players)

count_female_players = purchase_data_df.loc[purchase_data_df["Gender"] == "Female"]
count_female_players
female_count = len(count_female_players)

count_other_players = purchase_data_df.loc[purchase_data_df["Gender"] == "Other / Non-Disclosed"]
count_other_players
other_count = len(count_other_players)

summary_count_gender_df = pd.DataFrame({"Male Players": [male_count],
                                        "Female Players": [female_count],
                                        "Other Players": [other_count],})

summary_count_gender_df.head()
# Out:
#    Male Players  Female Players  Other Players
# 0           652             113             15

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
purchasing_analysis_male = purchase_data_df.loc[purchase_data_df["Gender"] == "Male"]
purchasing_analysis_male
# Out:
#      Purchase ID             SN  Age Gender  Item ID  \
# 0              0        Lisim78   20   Male      108
# 1              1    Lisovynya38   40   Male      143
# 2              2     Ithergue48   24   Male       92
# 3              3  Chamassasya86   24   Male      100
# 4              4      Iskosia90   23   Male      131
# ..           ...            ...  ...    ...      ...
# 774          774     Jiskjask80   11   Male       92
# 776          776         Iral74   21   Male      164
# 777          777     Yathecal72   20   Male       67
# 778          778        Sisur91    7   Male       92
# 779          779      Ennrian78   24   Male       50
#
#                                      Item Name  Price
# 0    Extraction, Quickblade Of Trembling Hands   3.53
# 1                            Frenzied Scimitar   1.56
# 2                                 Final Critic   4.88
# 3                                  Blindscythe   3.27
# 4                                         Fury   1.44
# ..                                         ...    ...
# 774                               Final Critic   4.19
# 776                           Exiled Doomblade   1.63
# 777      Celeste, Incarnation of the Corrupted   3.46
# 778                               Final Critic   4.19
# 779                                       Dawn   4.60
#
# [652 rows x 7 columns]

# %%
male_SN_group = purchasing_analysis_male.groupby("SN")

purchase_count = male_SN_group["Item Name"].value_counts()

purchase_price = male_SN_group["Price"].mean()

purchase_average = male_SN_group["Price"].sum()

summary_male_purchase_df = pd.DataFrame({"Purchase count": [purchase_count],
                                        "Average Purchase Price": [purchase_price],
                                        "Average Purchase": [purchase_average]})

summary_male_purchase_df.head()
# Out:
#                                       Purchase count  \
# 0  SN            Item Name                       ...
#
#                               Average Purchase Price  \
# 0  SN
# Adairialis76    2.280000
# Aeda94          4....
#
#                                     Average Purchase
# 0  SN
# Adairialis76    2.28
# Aeda94          4.91
# A...

# %%
purchasing_analysis_female = purchase_data_df.loc[purchase_data_df["Gender"] == "Female"]
purchasing_analysis_female
# Out:
#      Purchase ID               SN  Age  Gender  Item ID  \
# 15            15        Lisassa64   21  Female       98
# 18            18        Reunasu60   22  Female       82
# 38            38         Reulae52   10  Female      116
# 41            41        Assosia88   20  Female        7
# 55            55        Phaelap26   25  Female       84
# ..           ...              ...  ...     ...      ...
# 731          731         Eudanu84   22  Female       12
# 740          740        Reunasu60   22  Female      127
# 754          754  Pheosurllorin41   23  Female       79
# 767          767          Ilmol66    8  Female       92
# 775          775       Aethedru70   21  Female       60
#
#                         Item Name  Price
# 15    Deadline, Voice Of Subtlety   2.89
# 18                        Nirvana   4.90
# 38        Renewed Skeletal Katana   4.18
# 41   Thorn, Satchel of Dark Souls   1.33
# 55                     Arcane Gem   3.79
# ..                            ...    ...
# 731                         Dawne   1.02
# 740  Heartseeker, Reaver of Souls   3.92
# 754           Alpha, Oath of Zeal   4.05
# 767                  Final Critic   4.88
# 775                          Wolf   3.54
#
# [113 rows x 7 columns]

# %%
female_SN_group = purchasing_analysis_female.groupby("SN")

purchase_count = female_SN_group["Item Name"].value_counts()

purchase_price = female_SN_group["Price"].mean()

purchase_average = female_SN_group["Price"].sum()

summary_female_purchase_df = pd.DataFrame({"Purchase count": [purchase_count],
                                        "Average Purchase Price": [purchase_price],
                                        "Average Purchase": [purchase_average]})

summary_female_purchase_df.head()
# Out:
#                                       Purchase count  \
# 0  SN             Item Name                      ...
#
#                               Average Purchase Price  \
# 0  SN
# Adastirin33      4.480000
# Aerithllora36    ...
#
#                                     Average Purchase
# 0  SN
# Adastirin33      4.48
# Aerithllora36    8.64...

# %%
purchasing_analysis_other = purchase_data_df.loc[purchase_data_df["Gender"] == "Other / Non-Disclosed"]
purchasing_analysis_other
# Out:
#      Purchase ID            SN  Age                 Gender  Item ID  \
# 9              9   Chanosian48   35  Other / Non-Disclosed      136
# 22            22  Siarithria38   38  Other / Non-Disclosed       24
# 82            82    Haerithp41   16  Other / Non-Disclosed      160
# 111          111      Sundim98   21  Other / Non-Disclosed       41
# 228          228   Jiskirran77   20  Other / Non-Disclosed       80
# 237          237     Idairin51   20  Other / Non-Disclosed       16
# 242          242     Eodaisu60   16  Other / Non-Disclosed       39
# 291          291     Idairin51   20  Other / Non-Disclosed       35
# 350          350     Rairith81   15  Other / Non-Disclosed       34
# 401          401      Lirtim36   15  Other / Non-Disclosed       46
# 484          484   Chanosian48   35  Other / Non-Disclosed       39
# 549          549    Maluncil97   25  Other / Non-Disclosed      146
# 629          629    Maluncil97   25  Other / Non-Disclosed      107
# 637          637        Airi27   24  Other / Non-Disclosed      163
# 747          747  Siarithria38   38  Other / Non-Disclosed      146
#
#                                 Item Name  Price
# 9            Ghastly Adamantite Protector   3.58
# 22                          Warped Fetish   3.81
# 82                             Azurewrath   4.40
# 111                                 Orbit   4.75
# 228                             Dreamsong   3.39
# 237                       Restored Bauble   3.55
# 242  Betrayal, Whisper of Grieving Widows   3.94
# 291              Heartless Bone Dualblade   3.45
# 350                       Retribution Axe   2.22
# 401               Hopeless Ebon Dualblade   1.33
# 484  Betrayal, Whisper of Grieving Widows   3.94
# 549                  Warped Iron Scimitar   3.10
# 629             Splitter, Foe Of Subtlety   2.18
# 637                  Thunderfury Scimitar   3.45
# 747                  Warped Iron Scimitar   3.10

# %%
other_SN_group = purchasing_analysis_other.groupby("SN")

purchase_count = other_SN_group["Item Name"].value_counts()

purchase_price = other_SN_group["Price"].mean()

purchase_average = other_SN_group["Price"].sum()

summary_other_purchase_df = pd.DataFrame({"Purchase count": [purchase_count],
                                        "Average Purchase Price": [purchase_price],
                                        "Average Purchase": [purchase_average]})

summary_other_purchase_df.head()
# Out:
#                                       Purchase count  \
# 0  SN            Item Name                       ...
#
#                               Average Purchase Price  \
# 0  SN
# Airi27          3.450
# Chanosian48     3.760...
#
#                                     Average Purchase
# 0  SN
# Airi27          3.45
# Chanosian48     7.52
# E...

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
print(purchase_data_df["Age"].max())
print(purchase_data_df["Age"].min())
# Out:
# 45
# 7

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
bins = [0, 5, 10, 15, 20, 25, 30, 35, 40, 50]
group_labels = ["0 to 5", "6 to 10", "11 to 15", "16 to 20", "21 to 25", "26 to 30", "31 to 35", "36 to 40", "41 to 50"]

# %%
pd.cut(purchase_data_df["Age"], bins, labels=group_labels).head()
# Out:
# 0    16 to 20
# 1    36 to 40
# 2    21 to 25
# 3    21 to 25
# 4    21 to 25
# Name: Age, dtype: category
# Categories (9, object): [0 to 5 < 6 to 10 < 11 to 15 < 16 to 20 ... 26 to 30 < 31 to 35 < 36 to 40 < 41 to 50]

# %%
purchase_data_df["Age"] = pd.cut(purchase_data_df["Age"], bins, labels=group_labels)
purchase_data_df.head()
# Out:
#    Purchase ID             SN       Age Gender  Item ID  \
# 0            0        Lisim78  16 to 20   Male      108
# 1            1    Lisovynya38  36 to 40   Male      143
# 2            2     Ithergue48  21 to 25   Male       92
# 3            3  Chamassasya86  21 to 25   Male      100
# 4            4      Iskosia90  21 to 25   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
purchase_data_group = purchase_data_df.groupby(["SN"])
purchase_data_comparison_df = purchase_data_group.mean()
purchase_data_comparison_df

purchase_data_comparison_df["Total"] = purchase_data_comparison_df.sum(axis=1)
purchase_data_comparison_df["Total"]

topspenders_purchase_df = purchase_data_comparison_df.sort_values(["Total"], ascending=False)
topspenders_purchase_df.head()
# Out:
#                 Purchase ID  Item ID  Price   Total
# SN
# Frichirranya75        753.0    178.0   4.23  935.23
# Iljask75              750.0    167.0   3.61  920.61
# Ilosian36             769.0    145.0   4.58  918.58
# Aidaira26             730.0    178.0   4.23  912.23
# Aellyria80            746.0    159.0   3.08  908.08

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, average item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
most_popular_df = purchase_data_df[["Item ID", "Item Name", "Price"]]
most_popular_df.head()
# Out:
#    Item ID                                  Item Name  Price
# 0      108  Extraction, Quickblade Of Trembling Hands   3.53
# 1      143                          Frenzied Scimitar   1.56
# 2       92                               Final Critic   4.88
# 3      100                                Blindscythe   3.27
# 4      131                                       Fury   1.44

# %%
average_price_mostpopular_item = most_popular_df["Price"].mean()
print(average_price_mostpopular_item)
# Out:
# 3.050987179487176

# %%
most_popular_group = most_popular_df.groupby(["Item ID", "Item Name"])
most_popular_group_work_df = pd.DataFrame(most_popular_group["Price"].value_counts())
most_popular_group_work_df.head()
most_popular_group_work_df = most_popular_group_work_df.rename(
    columns={"Price": "Purchase Count"})

most_popular_group_work_df = most_popular_group_work_df.reset_index()
most_popular_group_work_df.head()
# Out:
#    Item ID     Item Name  Price  Purchase Count
# 0        0      Splinter   1.28               4
# 1        1      Crucifer   3.26               3
# 2        1      Crucifer   1.99               1
# 3        2       Verdict   2.48               6
# 4        3  Phantomlight   2.49               6

# %%
most_popular_group_work_df["Total"] = most_popular_group_work_df.sum(axis=1)
most_popular_group_work_df["Total"]
# Out:
# 0        31.68
# 1        43.56
# 2        23.94
# 3        62.88
# 4        68.94
#         ...
# 178    1165.38
# 179    1136.88
# 180    1125.96
# 181    1134.18
# 182    1122.54
# Name: Total, Length: 183, dtype: float64

# %%
most_popular_group_work_df = most_popular_group_work_df.merge(most_popular_group_work_df["Total"], on="Item ID")
most_popular_group_work_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-64-ef6fac3e8316> in <module>
# ----> 1 most_popular_group_work_df = most_popular_group_work_df.merge(most_popular_group_work_df["Total"], on="Item ID")
#       2 most_popular_group_work_df.head()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    7282         from pandas.core.reshape.merge import merge
#    7283
# -> 7284         return merge(
#    7285             self,
#    7286             right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      71     validate=None,
#      72 ) -> "DataFrame":
# ---> 73     op = _MergeOperation(
#      74         left,
#      75         right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     625             self.right_join_keys,
#     626             self.join_names,
# --> 627         ) = self._get_merge_keys()
#     628
#     629         # validate the merge keys dtypes. We may need to coerce
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _get_merge_keys(self)
#     981                     if not is_rkey(rk):
#     982                         if rk is not None:
# --> 983                             right_keys.append(right._get_label_or_level_values(rk))
#     984                         else:
#     985                             # work-around for merge_asof(right_index=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1690             values = self.axes[axis].get_level_values(key)._values
#    1691         else:
# -> 1692             raise KeyError(key)
#    1693
#    1694         # Check for duplicates
#
# KeyError: 'Item ID'

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame

# %%
most_profitable_items_df = most_popular_group_work_df.sort_values(["Total Purchase Value"], ascending=False)
most_profitable_items_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-31100612e912> in <module>
# ----> 1 most_profitable_items_df = most_popular_group_work_df.sort_values(["Total Purchase Value"], ascending=False)
#       2 most_profitable_items_df.head()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index)
#    4925
#    4926             by = by[0]
# -> 4927             k = self._get_label_or_level_values(by, axis=axis)
#    4928
#    4929             if isinstance(ascending, (tuple, list)):
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1690             values = self.axes[axis].get_level_values(key)._values
#    1691         else:
# -> 1692             raise KeyError(key)
#    1693
#    1694         # Check for duplicates
#
# KeyError: 'Total Purchase Value'
